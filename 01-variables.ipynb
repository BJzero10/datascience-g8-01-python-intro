# %%
print("Hola mundo!")
# Out:
# Hola mundo!

# %%
nombre: str = "Jesus Aldair"
apellido: str = "Sullon Silva"
print(f"{nombre} {apellido}")
# Out:
# Jesus Aldair Sullon Silva

# %%
edad: int = 26
print(f"Tengo {edad} años")
# Out:
# Tengo 26 años

# %%
sueldo: float = 500.50
print(f"Mi sueldo es: {sueldo}")
# Out:
# Mi sueldo es: 500.5

# %%
nombre: str = input("Ingrese su nombre: ")
apellido: str = input("Ingrese su apellido: ")
print(f"{nombre} {apellido}")
# Out:
# jesus sullon
